# %%
from abc import ABC, abstractmethod
from __future__ import annotations
import numpy as np
import tensor

# %%
# dataset class

class Dataset(ABC):
    """convert any data to tensor type"""
    @abstractmethod
    def __getitem__(self, idx):
        ...
        
    @abstractmethod
    def __len__(self):
        ...

# %%
# Subset class

class Subset(Dataset):
    """create a subset of a list of indices from dataset class"""
    def __init__(self, dataset: Dataset, indices: list = None):
        super().__init__()
        self.indices = indices
        self.dataset = dataset

    def __getitem__(self, idx):
        dx = self.indices[idx]
        return self.dataset[dx]

    def __len__(self):
        return len(self.indices)

# %%
# dataloader class

class Dataloader:
    '''Dataloader class to create a dataloader'''
    def __init__(self, dataset: Dataset, shuffle: bool, drop_last: bool = True, batch_size: int = 32, seed=42):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.rng = np.random.default_rng(seed)
    
    def __iter__(self):
        N = len(self.dataset)
        indices = list(range(N))
        
        if self.shuffle:
            self.rng.shuffle(indices)

        for i in range(0, N, self.batch_size):
            batch_idx = indices[i: i+self.batch_size]

            batch_samples = [self.dataset[x] for x in batch_idx]
            Xs, ys = zip(*batch_samples)
            
            yield tensor.tensor(Xs), tensor.tensor(ys)

    def __len__(self):
        return len(self.dataset) // self.batch_size

# %%
# trainer class

class trainer:
    '''Manages the epoch loop and the batch loop (per epoch) to train a model (using a dataloader to get mini batches) 
    '''
    def __init__(self, model, loss_fn, train_loader, optimizer, val_loader=None, callbacks:list = [None], epochs=32):
        self.model = model
        self.optimizer = optimizer
        self.loss_fn = loss_fn
        self.train_loader = train_loader
        self.epochs = epochs
        if val_loader: self.val_loader = val_loader

        # internal -- to be update and used by callbacks
        self.epoch = 0
        self.global_step = 0
        self.batch_idx = 0
        self._loss = float(0) # latest loss per batch
        self.metrics = dict()
        
    # internal callbacks
    def on_batch_begin(): 
        self.global_step += 1
        batch_size = dataloader.batch_size
        data_len = len(dataloader.dataset)
        pass

        
    def on_batch_end(): pass
    def on_epoch_begin(): pass
    def on_epoch_end(): pass
        
    def fit(self):
        for epoch in range(self.epochs):
            self.on_epoch_begin()
            for i, (X, y) in enumerate(self.train_dataloader):
                self.on_batch_begin()
                
                #fp 
                yhat = self.model(X)
        
                #loss
                loss = self.loss_fn(yhat, y)
        
                # zero grad
                model.zero_grad()
        
                # backprop
                loss.backward()
        
                # step -- update
                optimizer.step()

                self.on_batch_end()
            self.on_epoch_end()

# %%
# testing dataset
class myData(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __getitem__(self, idx):
        return (self.X[idx], self.y[idx])

    def __len__(self):
        return len(X)

# %%
X = np.random.randn(100, 2)
y = np.zeros(100, )

data = myData(X, y)
len(data) # len
data[10] # getitem
# Out:
# (array([-1.81362299, -1.18700452]), np.float64(0.0))

# %%
# testing subset
sub = Subset(data, [0, 1, 2, 3, 4, 5])
sub[0], len(sub)
# Out:
# ((array([-0.84213977,  2.07469566]), np.float64(0.0)), 6)

# %%
# testing dataloader
dataloader = Dataloader(dataset=data, shuffle=True, batch_size = 10)

# %%
# testing dataloader
epochs = 5
for e in range(epochs):
    print(f'e={e}')
    for i, (xs, ys) in enumerate(dataloader):
        print('  batch =', i)
        print('   first sample:', xs[0], ys[0])
# Out:
# e=0
#   batch = 0
#    first sample: tensor(data=[0.9377148  0.23853226], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[ 0.64229688 -0.94382451], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[0.85365835 0.67456539], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[ 0.43967414 -0.92555435], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[ 0.02231461 -0.10005181], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[-0.12066239  0.30567677], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[0.13216014 1.83194883], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[0.41562636 0.10621667], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[0.84341852 1.14717096], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[-0.35730685  0.39781735], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=1
#   batch = 0
#    first sample: tensor(data=[0.18759639 0.82687531], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[-0.45257337  1.49681181], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[0.29016648 0.06870665], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[-0.51712494 -0.84226415], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[ 1.19310874 -0.71415451], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[0.90846462 0.26199868], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[1.25657064 1.55141389], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[0.48893957 0.12059448], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[-0.71138597  0.82910961], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[ 0.2360443  -2.51258068], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=2
#   batch = 0
#    first sample: tensor(data=[-0.19898093  1.26804218], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[ 0.26248142 -0.66551432], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[ 1.07448345 -0.82981743], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[-0.74899424 -0.28403022], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[1.22034122 1.34676701], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[ 0.15945038 -0.29739416], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[0.36274374 1.19746969], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[0.85365835 0.67456539], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[2.24978863 0.50735201], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[ 0.21700843 -1.62637791], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=3
#   batch = 0
#    first sample: tensor(data=[-0.24163804 -0.20338909], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[0.76435294 0.19419686], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[-0.21951846 -1.57175438], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[0.12874026 1.61255696], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[1.75235358 0.68379274], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[-0.94151755  0.08602408], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[-0.12066239  0.30567677], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[-0.19298099 -0.27973169], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[-1.81362299 -1.18700452], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[0.13216014 1.83194883], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=4
#   batch = 0
#    first sample: tensor(data=[-0.47070809 -0.27532776], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[1.22034122 1.34676701], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[ 1.76603024 -1.34033461], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[ 0.2360443  -2.51258068], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[0.58963855 0.71034413], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[0.85365835 0.67456539], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[0.18759639 0.82687531], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[-0.08081056  0.13221891], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[-0.7229104  -0.99779983], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[-0.19898093  1.26804218], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
