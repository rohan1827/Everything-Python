# %%
from abc import ABC, abstractmethod
from __future__ import annotations
import numpy as np
import tensor

# %%
# dataset class

class Dataset(ABC):
    """convert any data to tensor type"""
    @abstractmethod
    def __getitem__(self, idx):
        ...
        
    @abstractmethod
    def __len__(self):
        ...

# %%
# Subset class

class Subset(Dataset):
    """create a subset of a list of indices from dataset class"""
    def __init__(self, dataset: Dataset, indices: list = None):
        super().__init__()
        self.indices = indices
        self.dataset = dataset

    def __getitem__(self, idx):
        dx = self.indices[idx]
        return self.dataset[dx]

    def __len__(self):
        return len(self.indices)

# %%
# dataloader class

class Dataloader:
    '''Dataloader class to create a dataloader'''
    def __init__(self, dataset: Dataset, shuffle: bool, drop_last: bool = True, batch_size: int = 32, seed=42):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.drop_last = drop_last
        self.rng = np.random.default_rng(seed)
    
    def __iter__(self):
        N = len(self.dataset)
        indices = list(range(N))
        
        if self.shuffle:
            self.rng.shuffle(indices)

        for i in range(0, N, self.batch_size):
            batch_idx = indices[i: i+self.batch_size]

            batch_samples = [self.dataset[x] for x in batch_idx]
            Xs, ys = zip(*batch_samples)
            
            yield tensor.tensor(Xs), tensor.tensor(ys)

    def __len__(self):
        return len(self.dataset) // self.batch_size

# %%
# trainer class

class trainer:
    '''Manages the epoch loop and the batch loop (per epoch) to train a model (using a dataloader to get mini batches) 
    '''
    def __init__(self, model, loss_fn, train_loader, optimizer, val_loader=None, callbacks:list = [None], epochs=32):
        self.model = model
        self.optimizer = optimizer
        self.loss_fn = loss_fn
        self.train_loader = train_loader
        self.epochs = epochs
        if val_loader: self.val_loader = val_loader

        # internal -- to be update and used by callbacks
        self.epoch = 0
        self.global_step = 0
        self.batch_idx = 0
        self._loss = float(0) # latest loss per batch
        self.metrics = dict()
        

    def on_batch_begin(): pass
    def on_batch_end(): pass
    def on_epoch_begin(): pass
    def on_epoch_end(): pass
        
    def fit(self):
        for epoch in range(self.epochs):
            self.on_epoch_begin()
            for i, (X, y) in enumerate(self.train_dataloader):
                self.on_batch_begin()
                
                #fp 
                yhat = self.model(X)
        
                #loss
                loss = self.loss_fn(yhat, y)
        
                # zero grad
                model.zero_grad()
        
                # backprop
                loss.backward()
        
                # step -- update
                optimizer.step()

                self.on_batch_end()
            self.on_epoch_end()

# %%
# testing dataset
class myData(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __getitem__(self, idx):
        return (self.X[idx], self.y[idx])

    def __len__(self):
        return len(X)

# %%
X = np.random.randn(100, 2)
y = np.zeros(100, )

data = myData(X, y)
len(data) # len
data[10] # getitem
# Out:
# (array([-0.04131592, -1.92517726]), np.float64(0.0))

# %%
# testing subset
sub = Subset(data, [0, 1, 2, 3, 4, 5])
sub[0], len(sub)
# Out:
# ((array([-1.65958253,  1.16754168]), np.float64(0.0)), 6)

# %%
# testing dataloader
dataloader = Dataloader(dataset=data, shuffle=True, batch_size = 10)

# %%
# testing dataloader
epochs = 5
for e in range(epochs):
    print(f'e={e}')
    for i, (xs, ys) in enumerate(loader):
        print('  batch =', i)
        print('   first sample:', xs[0], ys[0])
# Out:
# e=0
#   batch = 0
#    first sample: tensor(data=[0.08691567 0.87841543], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[-1.51873099  0.54278444], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[-0.79319875 -0.0043415 ], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[ 1.26684763 -1.89600803], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[-1.15141806  1.77653306], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[ 1.11954504 -0.82672548], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[-0.4838308  -0.43367093], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[0.81701668 0.29352133], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[ 0.15112584 -0.37611425], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[ 0.63265371 -0.75755157], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=1
#   batch = 0
#    first sample: tensor(data=[ 1.00836556 -0.30972635], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[ 0.34168961 -0.21905822], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[-0.48058876 -1.52609053], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[-0.2481793   0.33865698], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[-0.03160832  0.28889626], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[-0.39679339 -0.40096166], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[-0.49410941 -1.07155701], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[-0.0671705  0.2637822], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[-0.8273677   1.40200194], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[0.65487059 0.78302628], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=2
#   batch = 0
#    first sample: tensor(data=[-0.33333387 -1.06384576], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[0.06161513 0.19219481], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[0.03915692 0.80300747], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[0.01100149 0.2222308 ], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[ 0.42903463 -1.01446059], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[-0.33383357 -1.51878248], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[ 0.20532017 -1.08778328], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[1.32973948 1.69634512], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[ 1.14633927 -0.81973225], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[0.54952595 0.73920875], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=3
#   batch = 0
#    first sample: tensor(data=[0.77086166 1.22384049], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[ 0.77010292 -0.08228283], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[-1.63220143  0.08565704], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[-0.2536775   0.77970619], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[-1.28430618 -0.05223923], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[-1.15141806  1.77653306], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[1.0188136  0.25720708], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[ 0.63265371 -0.75755157], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[ 0.68708332 -0.73586239], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[-0.0274406  -0.60368829], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
# e=4
#   batch = 0
#    first sample: tensor(data=[ 2.50468491 -0.94255116], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 1
#    first sample: tensor(data=[-0.03160832  0.28889626], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 2
#    first sample: tensor(data=[-0.53570984 -0.39750277], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 3
#    first sample: tensor(data=[-0.0671705  0.2637822], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 4
#    first sample: tensor(data=[-0.48521581 -1.40236305], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 5
#    first sample: tensor(data=[-0.39679339 -0.40096166], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 6
#    first sample: tensor(data=[0.7659649  0.81275594], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 7
#    first sample: tensor(data=[-1.63220143  0.08565704], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 8
#    first sample: tensor(data=[-0.0609057   2.57920503], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
#   batch = 9
#    first sample: tensor(data=[-0.49410941 -1.07155701], grad=[0. 0.] shape=(2,)) tensor(data=0.0, grad=0.0 shape=())
